# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/rareylab/proteins_plus_examples/blob/main/notebooks/Structureprofiler_example.ipynb)

# %% [markdown]
# # StructureProfiler: an all-in-one tool for 3D protein structure profiling
#
# In this notebook we show you how to use the StructureProfiler for the automatic profiling of a given protein structure. The profiling is objective and based on the most frequently applied selection criteria currently in use to assemble benchmark datasets.
# To do so the StructureProfiler requires a protein file. If an electron density map (as file or PDB code) is uploaded the StructureProfiler additionaly includes filter criteria depending on EDIAscorer. In addition, it is possible to include a ligand that is of interest.
#
# For further information:
# [StructureProfiler: an all-in-one tool for 3D protein structure profiling
# Agnes Meyder, Stefanie Kampen, Jochen Sieg, Rainer Fährrolfes, Nils-Ole Friedrich, Florian Flachsenberg, and Matthias Rarey,
# Bioinformatics, 2019 35 (5), 874–876](https://academic.oup.com/bioinformatics/article/35/5/874/5075170)

# %% [markdown]
# Note:NGLview triggers the Colab code snippet sidebar every time a structure is visualized. Don't close it but resize it. In addition, sometimes the NGL views stay white and no structure is shown. In this case just run the cell again.

# %%
# colab allow nglview plugin
from google.colab import output
output.enable_custom_widget_manager()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_112788/50361146.py in <module>
#       1 # colab allow nglview plugin
# ----> 2 from google.colab import output
#       3 output.enable_custom_widget_manager()
#
# ModuleNotFoundError: No module named 'google'

# %%
# colab install dependencies
# !pip install biopython &>> output.log
# !pip install nglview &>> output.log
# !pip install rdkit-pypi &>> output.log

# %%
# imports
import json
import os
import io
from pathlib import Path
import requests
import sys
import time
import pandas as pd
from urllib.parse import urljoin

from Bio.PDB import *
import nglview as nv
from rdkit import Chem

# %%
#@title function for coloring results table (unhide if you're interested)

def table_style(row):
    """Creates color schema for result Table, rowwise
    
    :param row: Array of values in single row of result table
    :type row: array
    :return: list with color for each field in row
    :rtype: list
    """
    color_schema = list()
    if row.name == 'EDIAm' or row.name == 'residueEDIATest':
        color = 'lightblue'
        style = 'background-color: ' + color
        color_schema.append(style)
        return color_schema*len(row.values)  
    if 'Test' in row.name or 'Clash' in row.name:
        for i in range(len(row.values)):
            color = 'white'
            if row.values[i] == False:
                color = 'red'
            style = 'background-color: ' + color
            color_schema.append(style)
        return color_schema
    elif row.name == 'noCrystalContacts' or row.name == 'noAltLocs':
        for i in range(len(row.values)):
            color = 'white'
            if row.values[i] == False:
                color = 'red'
            style = 'background-color: ' + color
            color_schema.append(style)
        return color_schema
    else:
        style = 'background-color: white'
        color_schema.append(style)
        return (color_schema)*len(row.values)

# %%
# constants
PROTEINS_PLUS_URL = 'https://proteins.plus/api/v2/'
UPLOAD = urljoin(PROTEINS_PLUS_URL, 'molecule_handler/upload/')
UPLOAD_JOBS = urljoin(PROTEINS_PLUS_URL, 'molecule_handler/upload/jobs/')
PROTEINS = urljoin(PROTEINS_PLUS_URL, 'molecule_handler/proteins/')
LIGANDS = urljoin(PROTEINS_PLUS_URL, 'molecule_handler/ligands/')
STRUCTUREPROFILER = urljoin(PROTEINS_PLUS_URL, 'structureprofiler/')
STRUCTUREPROFILER_JOBS = urljoin(PROTEINS_PLUS_URL, 'structureprofiler/jobs/')
OUTPUT_DATA = urljoin(PROTEINS_PLUS_URL, 'structureprofiler/output/')

# %%
#@title Utils functions to call API (unhide if you're interested)

# check server connection
try:
    response = requests.get(PROTEINS_PLUS_URL)
except requests.ConnectionError as error:
    if 'Connection refused' in str(error):
        print('WARNING: could not establish a connection to the server', file=sys.stderr)
    raise
    
def poll_job(job_id, poll_url, poll_interval=1, max_polls=10):
    """Poll the progress of a job
    
    Continuosly polls the server in regular intervals and updates the job information, especially the status.
    
    :param job_id: UUID of the job to poll
    :type job_id: str
    :param poll_url: URl to send the polling request to
    :type poll_url: str
    :param poll_interval: time interval between polls in seconds
    :type poll_interval: int
    :param max_polls: maximum number of times to poll before exiting
    :type max_polls: int
    :return: polled job
    :rtype: dict
    """
    job = requests.get(poll_url + job_id + '/').json()
    status = job['status']
    current_poll = 0
    while status == 'pending' or status == 'running':
        print(f'Job {job_id} is { status }')
        current_poll += 1
        if current_poll >= max_polls:
            print(f'Job {job_id} has not completed after {max_polls} polling requests' \
                  f' and {poll_interval * max_polls} seconds')
            return job
        time.sleep(poll_interval)
        job = requests.get(poll_url + job_id + '/').json()
        status = job['status']
    print(f'Job {job_id} completed with { status }')
    return job

# %% [markdown]
# You can use Structureprofiler for automatic, objective and customizable profiling of X-ray protein structures. Based on the most frequently applied selection criteria, the given protein structure is evaluated. Results are given for the Complex, the ActiveSites and Ligands.
#
# Let's take a look at the first protein by visualizing its structure.

# %%
# fetch the protein 4agm from the PDB
file_4agm = Path(PDBList().retrieve_pdb_file('4agm', file_format='pdb'))
os.rename(file_4agm, '4agm.pdb')
file_4agm = '4agm.pdb' # ProteinsPlus needs .pdb extension

# build a biopython protein
protein_structure = PDBParser().get_structure('4agm',file_4agm)
view = nv.show_biopython(protein_structure)
view.add_representation(repr_type='ball+stick', selection='ligand')
view
# Out:
# Downloading PDB structure '4agm'...
# /home/katharina/anaconda3/envs/examples/lib/python3.7/site-packages/Bio/PDB/StructureBuilder.py:92: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 3813.
#   PDBConstructionWarning,
# /home/katharina/anaconda3/envs/examples/lib/python3.7/site-packages/Bio/PDB/StructureBuilder.py:92: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 3835.
#   PDBConstructionWarning,
# /home/katharina/anaconda3/envs/examples/lib/python3.7/site-packages/Bio/PDB/StructureBuilder.py:92: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 3857.
#   PDBConstructionWarning,
# /home/katharina/anaconda3/envs/examples/lib/python3.7/site-packages/Bio/PDB/StructureBuilder.py:92: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 4161.
#   PDBConstructionWarning,
# NGLWidget()

# %% [markdown]
# We can upload a protein file and start a job like this:
#
# Note: Uploading a protein file is mandatory. However, there is an additional option to include an electron density map as well as a specific ligand.
#
# But let's keep it simple for now.

# %%
with open(file_4agm) as upload_file:
    query = {'protein_file': upload_file}
    job_submission = requests.post(STRUCTUREPROFILER, files=query).json()
structureprofiler_job = poll_job(job_submission['job_id'], STRUCTUREPROFILER_JOBS)
output_data = requests.get(OUTPUT_DATA + structureprofiler_job['output_data'] + '/').json()
# Out:
# Job 0917996b-cff2-45fd-a3d9-7d094cd86e1c completed with success

# %% [markdown]
# The Structureprofiler produces a single output called "output_data", which can be divided into three tables each about Complex, Active Sites and Ligands. Where possible, the specfic values are shown, otherwise it is indicated whether a test is passed, which means, that the filter criteria is fullfilled. Here the failed criteria are marked red.
# The number of columns in Ligands and ActiveSites tables differ between proteins, depending on the number of given Ligands and Active sites. The specific protein currently in question has two ligands shown in the structure above.

# %%
complex_data = pd.DataFrame.from_dict([output_data['output_data']['complex']])
complex_data = complex_data.transpose()
complex_data.style.apply(table_style, axis=1)
# Out:
# <style type="text/css">
# #T_2e6f8_row0_col0, #T_2e6f8_row1_col0, #T_2e6f8_row2_col0, #T_2e6f8_row3_col0, #T_2e6f8_row4_col0, #T_2e6f8_row5_col0, #T_2e6f8_row6_col0 {
#   background-color: white;
# }
# </style>
# <table id="T_2e6f8_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2e6f8_level0_row0" class="row_heading level0 row0" >DPI</th>
#       <td id="T_2e6f8_row0_col0" class="data row0 col0" >0.115000</td>
#     </tr>
#     <tr>
#       <th id="T_2e6f8_level0_row1" class="row_heading level0 row1" >rFree</th>
#       <td id="T_2e6f8_row1_col0" class="data row1 col0" >0.197000</td>
#     </tr>
#     <tr>
#       <th id="T_2e6f8_level0_row2" class="row_heading level0 row2" >rFactor</th>
#       <td id="T_2e6f8_row2_col0" class="data row2 col0" >0.173000</td>
#     </tr>
#     <tr>
#       <th id="T_2e6f8_level0_row3" class="row_heading level0 row3" >resolution</th>
#       <td id="T_2e6f8_row3_col0" class="data row3 col0" >1.520000</td>
#     </tr>
#     <tr>
#       <th id="T_2e6f8_level0_row4" class="row_heading level0 row4" >overfittingTest</th>
#       <td id="T_2e6f8_row4_col0" class="data row4 col0" >True</td>
#     </tr>
#     <tr>
#       <th id="T_2e6f8_level0_row5" class="row_heading level0 row5" >significanceTest</th>
#       <td id="T_2e6f8_row5_col0" class="data row5 col0" >True</td>
#     </tr>
#     <tr>
#       <th id="T_2e6f8_level0_row6" class="row_heading level0 row6" >complexStructureProfilerTests</th>
#       <td id="T_2e6f8_row6_col0" class="data row6 col0" >True</td>
#     </tr>
#   </tbody>
# </table>

# %%
ligand_data = pd.DataFrame.from_dict(output_data['output_data']['ligands'])
ligand_data.columns = ['Ligand_1', 'Ligand_2']
ligand_data.style.apply(table_style, axis=1)
# Out:
# <style type="text/css">
# #T_b9a72_row0_col0, #T_b9a72_row0_col1, #T_b9a72_row1_col0, #T_b9a72_row1_col1, #T_b9a72_row2_col0, #T_b9a72_row2_col1, #T_b9a72_row3_col0, #T_b9a72_row3_col1, #T_b9a72_row4_col0, #T_b9a72_row4_col1, #T_b9a72_row5_col0, #T_b9a72_row5_col1, #T_b9a72_row6_col0, #T_b9a72_row6_col1, #T_b9a72_row7_col0, #T_b9a72_row7_col1, #T_b9a72_row8_col0, #T_b9a72_row8_col1, #T_b9a72_row9_col0, #T_b9a72_row9_col1, #T_b9a72_row11_col0, #T_b9a72_row11_col1, #T_b9a72_row12_col0, #T_b9a72_row12_col1, #T_b9a72_row13_col0, #T_b9a72_row13_col1, #T_b9a72_row14_col0, #T_b9a72_row14_col1, #T_b9a72_row15_col0, #T_b9a72_row15_col1, #T_b9a72_row16_col0, #T_b9a72_row16_col1, #T_b9a72_row17_col1, #T_b9a72_row18_col0, #T_b9a72_row19_col0, #T_b9a72_row19_col1, #T_b9a72_row20_col0, #T_b9a72_row20_col1, #T_b9a72_row21_col0, #T_b9a72_row21_col1, #T_b9a72_row22_col0, #T_b9a72_row22_col1 {
#   background-color: white;
# }
# #T_b9a72_row10_col0, #T_b9a72_row10_col1, #T_b9a72_row17_col0, #T_b9a72_row18_col1, #T_b9a72_row23_col0, #T_b9a72_row23_col1 {
#   background-color: red;
# }
# </style>
# <table id="T_b9a72_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Ligand_1</th>
#       <th class="col_heading level0 col1" >Ligand_2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b9a72_level0_row0" class="row_heading level0 row0" >ID</th>
#       <td id="T_b9a72_row0_col0" class="data row0 col0" >400</td>
#       <td id="T_b9a72_row0_col1" class="data row0 col1" >400</td>
#     </tr>
#     <tr>
#       <th id="T_b9a72_level0_row1" class="row_heading level0 row1" >NROT</th>
#       <td id="T_b9a72_row1_col0" class="data row1 col0" >5</td>
#       <td id="T_b9a72_row1_col1" class="data row1 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_b9a72_level0_row2" class="row_heading level0 row2" >OWAB</th>
#       <td id="T_b9a72_row2_col0" class="data row2 col0" >18.200000</td>
#       <td id="T_b9a72_row2_col1" class="data row2 col1" >20.100000</td>
#     </tr>
#     <tr>
#       <th id="T_b9a72_level0_row3" class="row_heading level0 row3" >logP</th>
#       <td id="T_b9a72_row3_col0" class="data row3 col0" >1.070000</td>
#       <td id="T_b9a72_row3_col1" class="data row3 col1" >1.070000</td>
#     </tr>
#     <tr>
#       <th id="T_b9a72_level0_row4" class="row_heading level0 row4" >name</th>
#       <td id="T_b9a72_row4_col0" class="data row4 col0" >P86_A_400</td>
#       <td id="T_b9a72_row4_col1" class="data row4 col1" >P86_B_400</td>
#     </tr>
#     <tr>
#       <th id="T_b9a72_level0_row5" class="row_heading level0 row5" >chain</th>
#       <td id="T_b9a72_row5_col0" class="data row5 col0" >A</td>
#       <td id="T_b9a72_row5_col1" class="data row5 col1" >B</td>
#     </tr>
#     <tr>
#       <th id="T_b9a72_level0_row6" class="row_heading level0 row6" >HETCode</th>
#       <td id="T_b9a72_row6_col0" class="data row6 col0" >P86</td>
#       <td id="T_b9a72_row6_col1" class="data row6 col1" >P86</td>
#     </tr>
#     <tr>
#       <th id="T_b9a72_level0_row7" class="row_heading level0 row7" >noAltLocs</th>
#       <td id="T_b9a72_row7_col0" class="data row7 col0" >True</td>
#       <td id="T_b9a72_row7_col1" class="data row7 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_b9a72_level0_row8" class="row_heading level0 row8" >heavyAtoms</th>
#       <td id="T_b9a72_row8_col0" class="data row8 col0" >21</td>
#       <td id="T_b9a72_row8_col1" class="data row8 col1" >21</td>
#     </tr>
#     <tr>
#       <th id="T_b9a72_level0_row9" class="row_heading level0 row9" >stereoCenters</th>
#       <td id="T_b9a72_row9_col0" class="data row9 col0" >0</td>
#       <td id="T_b9a72_row9_col1" class="data row9 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_b9a72_level0_row10" class="row_heading level0 row10" >bondAnglesTest</th>
#       <td id="T_b9a72_row10_col0" class="data row10 col0" >False</td>
#       <td id="T_b9a72_row10_col1" class="data row10 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b9a72_level0_row11" class="row_heading level0 row11" >lipinskiDonors</th>
#       <td id="T_b9a72_row11_col0" class="data row11 col0" >1</td>
#       <td id="T_b9a72_row11_col1" class="data row11 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_b9a72_level0_row12" class="row_heading level0 row12" >maxAtomBFactor</th>
#       <td id="T_b9a72_row12_col0" class="data row12 col0" >0.000000</td>
#       <td id="T_b9a72_row12_col1" class="data row12 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b9a72_level0_row13" class="row_heading level0 row13" >bondLengthsTest</th>
#       <td id="T_b9a72_row13_col0" class="data row13 col0" >True</td>
#       <td id="T_b9a72_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_b9a72_level0_row14" class="row_heading level0 row14" >molecularWeight</th>
#       <td id="T_b9a72_row14_col0" class="data row14 col0" >514.000000</td>
#       <td id="T_b9a72_row14_col1" class="data row14 col1" >514.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b9a72_level0_row15" class="row_heading level0 row15" >HETExclusionTest</th>
#       <td id="T_b9a72_row15_col0" class="data row15 col0" >True</td>
#       <td id="T_b9a72_row15_col1" class="data row15 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_b9a72_level0_row16" class="row_heading level0 row16" >lipinskiAcceptors</th>
#       <td id="T_b9a72_row16_col0" class="data row16 col0" >3</td>
#       <td id="T_b9a72_row16_col1" class="data row16 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_b9a72_level0_row17" class="row_heading level0 row17" >noCrystalContacts</th>
#       <td id="T_b9a72_row17_col0" class="data row17 col0" >False</td>
#       <td id="T_b9a72_row17_col1" class="data row17 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_b9a72_level0_row18" class="row_heading level0 row18" >ringPlanarityTest</th>
#       <td id="T_b9a72_row18_col0" class="data row18 col0" >True</td>
#       <td id="T_b9a72_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b9a72_level0_row19" class="row_heading level0 row19" >torsionAnglesTest</th>
#       <td id="T_b9a72_row19_col0" class="data row19 col0" >True</td>
#       <td id="T_b9a72_row19_col1" class="data row19 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_b9a72_level0_row20" class="row_heading level0 row20" >nofPeptideResidues</th>
#       <td id="T_b9a72_row20_col0" class="data row20 col0" >0</td>
#       <td id="T_b9a72_row20_col1" class="data row20 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_b9a72_level0_row21" class="row_heading level0 row21" >SMARTSExklusionTest</th>
#       <td id="T_b9a72_row21_col0" class="data row21 col0" >True</td>
#       <td id="T_b9a72_row21_col1" class="data row21 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_b9a72_level0_row22" class="row_heading level0 row22" >noIntramolecularClash</th>
#       <td id="T_b9a72_row22_col0" class="data row22 col0" >True</td>
#       <td id="T_b9a72_row22_col1" class="data row22 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_b9a72_level0_row23" class="row_heading level0 row23" >ligandStructureProfilerTests</th>
#       <td id="T_b9a72_row23_col0" class="data row23 col0" >False</td>
#       <td id="T_b9a72_row23_col1" class="data row23 col1" >False</td>
#     </tr>
#   </tbody>
# </table>

# %%
active_site_data = pd.DataFrame.from_dict(output_data['output_data']['active_sites'])
active_site_data.columns = ['Active_site_1', 'Active_site_2']
active_site_data.style.apply(table_style, axis=1)
# Out:
# <style type="text/css">
# #T_c4a1d_row0_col0, #T_c4a1d_row0_col1, #T_c4a1d_row1_col0, #T_c4a1d_row1_col1, #T_c4a1d_row2_col0, #T_c4a1d_row2_col1, #T_c4a1d_row3_col0, #T_c4a1d_row3_col1, #T_c4a1d_row5_col0, #T_c4a1d_row5_col1, #T_c4a1d_row6_col0, #T_c4a1d_row6_col1, #T_c4a1d_row7_col0, #T_c4a1d_row7_col1, #T_c4a1d_row8_col0, #T_c4a1d_row8_col1 {
#   background-color: white;
# }
# #T_c4a1d_row4_col0, #T_c4a1d_row4_col1, #T_c4a1d_row9_col0, #T_c4a1d_row9_col1 {
#   background-color: red;
# }
# </style>
# <table id="T_c4a1d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Active_site_1</th>
#       <th class="col_heading level0 col1" >Active_site_2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c4a1d_level0_row0" class="row_heading level0 row0" >chains</th>
#       <td id="T_c4a1d_row0_col0" class="data row0 col0" >A,B</td>
#       <td id="T_c4a1d_row0_col1" class="data row0 col1" >A,B</td>
#     </tr>
#     <tr>
#       <th id="T_c4a1d_level0_row1" class="row_heading level0 row1" >ligand</th>
#       <td id="T_c4a1d_row1_col0" class="data row1 col0" >P86_A_400</td>
#       <td id="T_c4a1d_row1_col1" class="data row1 col1" >P86_B_400</td>
#     </tr>
#     <tr>
#       <th id="T_c4a1d_level0_row2" class="row_heading level0 row2" >noAltLocs</th>
#       <td id="T_c4a1d_row2_col0" class="data row2 col0" >True</td>
#       <td id="T_c4a1d_row2_col1" class="data row2 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c4a1d_level0_row3" class="row_heading level0 row3" >uniprotID</th>
#       <td id="T_c4a1d_row3_col0" class="data row3 col0" >P04637</td>
#       <td id="T_c4a1d_row3_col1" class="data row3 col1" >P04637</td>
#     </tr>
#     <tr>
#       <th id="T_c4a1d_level0_row4" class="row_heading level0 row4" >bondAnglesTest</th>
#       <td id="T_c4a1d_row4_col0" class="data row4 col0" >False</td>
#       <td id="T_c4a1d_row4_col1" class="data row4 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c4a1d_level0_row5" class="row_heading level0 row5" >bondLengthsTest</th>
#       <td id="T_c4a1d_row5_col0" class="data row5 col0" >True</td>
#       <td id="T_c4a1d_row5_col1" class="data row5 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c4a1d_level0_row6" class="row_heading level0 row6" >bFactorRatioTest</th>
#       <td id="T_c4a1d_row6_col0" class="data row6 col0" >True</td>
#       <td id="T_c4a1d_row6_col1" class="data row6 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c4a1d_level0_row7" class="row_heading level0 row7" >noIntermolecularClash</th>
#       <td id="T_c4a1d_row7_col0" class="data row7 col0" >True</td>
#       <td id="T_c4a1d_row7_col1" class="data row7 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c4a1d_level0_row8" class="row_heading level0 row8" >noIntramolecularClash</th>
#       <td id="T_c4a1d_row8_col0" class="data row8 col0" >True</td>
#       <td id="T_c4a1d_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c4a1d_level0_row9" class="row_heading level0 row9" >activeSiteStructureProfilerTests</th>
#       <td id="T_c4a1d_row9_col0" class="data row9 col0" >False</td>
#       <td id="T_c4a1d_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Let's talk briefly about the tests seen so far to get an idea what failing a test means.
# Most of the tests have cutoff values, that have not been explicitly mentioned yet. We will not be able to talk about all test. For more information, please read the paper mentioned in the introduction.
#
#
# Test|Description with default cutoffs
# -----|-----
# bondAnglesTest| no bond angle may deviate more than 16° from the VSEPR angle.
# bondLengthsTest|no bond length may deviate more than 0.2Å from the sum of the covalent radii.
# noCrystalContacts| no crystal symmetry contact is closer than 6Å to the ligand
# ringPlanarityTest| no aromatic ring with the maximum size of 6 differing by more than 20° from planarity
#
# *complexStructureProfilerTests*, *ligandStructureProfilerTests* and *activeSiteStructureProfilerTests* indicate whether __all__ respective tests have been passed.
#
# The protein we use for demonstration does not pass some ligand and active-site tests. However, whether this failed test make it unsuitable for use depends on the intended application.

# %% [markdown]
# Let's continue and try the same protein as before. This time we also upload a electron density map as well as a non-native ligand. The ligand NXG_A_1294 is from another protein (PDB Code: 4AGN).

# %%
# selector to extract the ligand we want from the biopython structure
class SingleResidueSelect(Select):
    
    def __init__(self,name,chain,identifier):
        """Selector to select specific residue from biopython structure.
        
        Residue can be amino acid, ligand, metal, water, etc.

        :param name: residue name
        :type name: str
        :param chain: chain id
        :type chain: str
        :param identifier: ligand infile id
        :type identifier int
        """
    
        self.name = name
        self.chain = chain
        self.identifier = identifier
    
    def accept_residue(self, residue):
        """Accept residue or refuses it
        
        :param name: residue name
        _type name: Bio.PDB.residue.residue
        :return 1 if residue should be selected 0 otherwise.
        :rtype: int
        """
        chain = residue.get_full_id()[2]
        identifier = residue.get_id()[1]
        if residue.get_resname() == self.name \
            and self.chain == chain \
            and self.identifier == identifier:
            return 1
        else:
            return 0
        
# fetch the protein 4AGN from the PDB
file_4agn = Path(PDBList().retrieve_pdb_file('4agn', file_format='pdb'))
os.rename(file_4agn, '4agn.pdb')
file_4agn = '4agn.pdb' # ProteinsPlus needs .pdb extension

# build a biopython protein
structure_for_ligand = PDBParser().get_structure('4agn',file_4agn)

#save ligand NXG_A_1294 to PDB file using biopython
pdbio = PDBIO()
pdbio.set_structure(structure_for_ligand)
pdbio.save('NXG_A_1294.pdb', SingleResidueSelect('NXG', 'A', 1294))
#read ligand again and save it as SDF to rdkit
mol_NXG_A_1294 = Chem.MolFromPDBFile('NXG_A_1294.pdb')
mol_NXG_A_1294.SetProp('_Name', 'NXG_A_1294')
with Chem.SDWriter('NXG_A_1294.sdf') as w:
    w.write(mol_NXG_A_1294)
print('Saved ligand to NXG_A_1294.sdf')
# Out:
# Downloading PDB structure '4agn'...
# Saved ligand to NXG_A_1294.sdf
# /home/katharina/anaconda3/envs/examples/lib/python3.7/site-packages/Bio/PDB/StructureBuilder.py:92: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 3832.
#   PDBConstructionWarning,
# /home/katharina/anaconda3/envs/examples/lib/python3.7/site-packages/Bio/PDB/StructureBuilder.py:92: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 3857.
#   PDBConstructionWarning,
# /home/katharina/anaconda3/envs/examples/lib/python3.7/site-packages/Bio/PDB/StructureBuilder.py:92: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 3882.
#   PDBConstructionWarning,
# /home/katharina/anaconda3/envs/examples/lib/python3.7/site-packages/Bio/PDB/StructureBuilder.py:92: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 4179.
#   PDBConstructionWarning,

# %%
with open('NXG_A_1294.sdf') as upload_ligand_file:
    with open('4agm.pdb') as upload_file:
        query = {'protein_file': upload_file, 'ligand_file': upload_ligand_file}
        params = {'pdb_code': '4agm'}
        job_submission = requests.post(STRUCTUREPROFILER,files=query, data=params).json()
structureprofiler_job = poll_job(job_submission['job_id'], STRUCTUREPROFILER_JOBS,poll_interval=5, max_polls=100)
output_data = requests.get(OUTPUT_DATA + structureprofiler_job['output_data'] + '/').json()
# Out:
# Job 54694a8d-f997-4a3a-af56-d017f25361c1 completed with success

# %% [markdown]
# This call sent the PDB file of 4AGM, a PDB Code and the ligand file to the server. The PDB Code ist then used to retrieve the electron density map.
#
# We could also use a local density file. This would look like this:

# %%
#with open(TEST_FILES / '4agm.pdb') as upload_file:
#    with open(TEST_FILES / '4agm.ccp4', 'rb') as density_file:
#            with open(TEST_FILES / 'NXG_A_1294.sdf') as upload_ligand_file:
#                query = {'protein_file': upload_file}
#                params = {'pdb_code': '4agm'}
#                job_submission = requests.post(STRUCTUREPROFILER,files=query).json()
#structureprofiler_job = poll_job(job_submission['job_id'], STRUCTUREPROFILER_JOBS,poll_interval=5, max_polls=100 )
#output_data = requests.get(OUTPUT_DATA + structureprofiler_job['output_data']).json()

# %% [markdown]
# Let's take a look at our results. As you can see the Ligand and Active Sites tables have now additional rows referring to tests depending on EDIA (marked blue). Therefore these entries are only in the results if an electron density map was given. They also have an additional column that refers to the non-native input ligand (Ligand_3).

# %%
complex_data = pd.DataFrame.from_dict([output_data['output_data']['complex']])
ligand_data = pd.DataFrame.from_dict(output_data['output_data']['ligands'])
active_sites_data = pd.DataFrame.from_dict(output_data['output_data']['active_sites'])

# %%
complex_data = pd.DataFrame.from_dict([output_data['output_data']['complex']])
complex_data = complex_data.transpose()
complex_data.style.apply(table_style, axis=1)
# Out:
# <style type="text/css">
# #T_cc1b0_row0_col0, #T_cc1b0_row1_col0, #T_cc1b0_row2_col0, #T_cc1b0_row3_col0, #T_cc1b0_row4_col0, #T_cc1b0_row5_col0, #T_cc1b0_row6_col0 {
#   background-color: white;
# }
# </style>
# <table id="T_cc1b0_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cc1b0_level0_row0" class="row_heading level0 row0" >DPI</th>
#       <td id="T_cc1b0_row0_col0" class="data row0 col0" >0.115000</td>
#     </tr>
#     <tr>
#       <th id="T_cc1b0_level0_row1" class="row_heading level0 row1" >rFree</th>
#       <td id="T_cc1b0_row1_col0" class="data row1 col0" >0.197000</td>
#     </tr>
#     <tr>
#       <th id="T_cc1b0_level0_row2" class="row_heading level0 row2" >rFactor</th>
#       <td id="T_cc1b0_row2_col0" class="data row2 col0" >0.173000</td>
#     </tr>
#     <tr>
#       <th id="T_cc1b0_level0_row3" class="row_heading level0 row3" >resolution</th>
#       <td id="T_cc1b0_row3_col0" class="data row3 col0" >1.520000</td>
#     </tr>
#     <tr>
#       <th id="T_cc1b0_level0_row4" class="row_heading level0 row4" >overfittingTest</th>
#       <td id="T_cc1b0_row4_col0" class="data row4 col0" >True</td>
#     </tr>
#     <tr>
#       <th id="T_cc1b0_level0_row5" class="row_heading level0 row5" >significanceTest</th>
#       <td id="T_cc1b0_row5_col0" class="data row5 col0" >True</td>
#     </tr>
#     <tr>
#       <th id="T_cc1b0_level0_row6" class="row_heading level0 row6" >complexStructureProfilerTests</th>
#       <td id="T_cc1b0_row6_col0" class="data row6 col0" >True</td>
#     </tr>
#   </tbody>
# </table>

# %%
ligand_data = pd.DataFrame.from_dict(output_data['output_data']['ligands'])
ligand_data.columns = ['Ligand_1', 'Ligand_2', 'Ligand_3']
ligand_data.style.apply(table_style, axis=1)
# Out:
# <style type="text/css">
# #T_eae8e_row0_col0, #T_eae8e_row0_col1, #T_eae8e_row0_col2, #T_eae8e_row1_col0, #T_eae8e_row1_col1, #T_eae8e_row1_col2, #T_eae8e_row2_col0, #T_eae8e_row2_col1, #T_eae8e_row2_col2, #T_eae8e_row3_col0, #T_eae8e_row3_col1, #T_eae8e_row3_col2, #T_eae8e_row4_col0, #T_eae8e_row4_col1, #T_eae8e_row4_col2, #T_eae8e_row6_col0, #T_eae8e_row6_col1, #T_eae8e_row6_col2, #T_eae8e_row7_col0, #T_eae8e_row7_col1, #T_eae8e_row7_col2, #T_eae8e_row8_col0, #T_eae8e_row8_col1, #T_eae8e_row8_col2, #T_eae8e_row9_col0, #T_eae8e_row9_col1, #T_eae8e_row9_col2, #T_eae8e_row10_col0, #T_eae8e_row10_col1, #T_eae8e_row10_col2, #T_eae8e_row12_col0, #T_eae8e_row12_col1, #T_eae8e_row12_col2, #T_eae8e_row13_col0, #T_eae8e_row13_col1, #T_eae8e_row13_col2, #T_eae8e_row14_col0, #T_eae8e_row14_col1, #T_eae8e_row15_col0, #T_eae8e_row15_col1, #T_eae8e_row15_col2, #T_eae8e_row16_col0, #T_eae8e_row16_col1, #T_eae8e_row16_col2, #T_eae8e_row17_col0, #T_eae8e_row17_col1, #T_eae8e_row17_col2, #T_eae8e_row18_col1, #T_eae8e_row19_col0, #T_eae8e_row19_col2, #T_eae8e_row20_col0, #T_eae8e_row20_col1, #T_eae8e_row21_col0, #T_eae8e_row21_col1, #T_eae8e_row21_col2, #T_eae8e_row22_col0, #T_eae8e_row22_col1, #T_eae8e_row22_col2, #T_eae8e_row23_col0, #T_eae8e_row23_col1, #T_eae8e_row23_col2 {
#   background-color: white;
# }
# #T_eae8e_row5_col0, #T_eae8e_row5_col1, #T_eae8e_row5_col2 {
#   background-color: lightblue;
# }
# #T_eae8e_row11_col0, #T_eae8e_row11_col1, #T_eae8e_row11_col2, #T_eae8e_row14_col2, #T_eae8e_row18_col0, #T_eae8e_row18_col2, #T_eae8e_row19_col1, #T_eae8e_row20_col2, #T_eae8e_row24_col0, #T_eae8e_row24_col1, #T_eae8e_row24_col2 {
#   background-color: red;
# }
# </style>
# <table id="T_eae8e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Ligand_1</th>
#       <th class="col_heading level0 col1" >Ligand_2</th>
#       <th class="col_heading level0 col2" >Ligand_3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eae8e_level0_row0" class="row_heading level0 row0" >ID</th>
#       <td id="T_eae8e_row0_col0" class="data row0 col0" >400</td>
#       <td id="T_eae8e_row0_col1" class="data row0 col1" >400</td>
#       <td id="T_eae8e_row0_col2" class="data row0 col2" >1294</td>
#     </tr>
#     <tr>
#       <th id="T_eae8e_level0_row1" class="row_heading level0 row1" >NROT</th>
#       <td id="T_eae8e_row1_col0" class="data row1 col0" >5</td>
#       <td id="T_eae8e_row1_col1" class="data row1 col1" >5</td>
#       <td id="T_eae8e_row1_col2" class="data row1 col2" >8</td>
#     </tr>
#     <tr>
#       <th id="T_eae8e_level0_row2" class="row_heading level0 row2" >OWAB</th>
#       <td id="T_eae8e_row2_col0" class="data row2 col0" >18.200000</td>
#       <td id="T_eae8e_row2_col1" class="data row2 col1" >20.100000</td>
#       <td id="T_eae8e_row2_col2" class="data row2 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_eae8e_level0_row3" class="row_heading level0 row3" >logP</th>
#       <td id="T_eae8e_row3_col0" class="data row3 col0" >3.280000</td>
#       <td id="T_eae8e_row3_col1" class="data row3 col1" >1.070000</td>
#       <td id="T_eae8e_row3_col2" class="data row3 col2" >1.340000</td>
#     </tr>
#     <tr>
#       <th id="T_eae8e_level0_row4" class="row_heading level0 row4" >name</th>
#       <td id="T_eae8e_row4_col0" class="data row4 col0" >P86_A_400</td>
#       <td id="T_eae8e_row4_col1" class="data row4 col1" >P86_B_400</td>
#       <td id="T_eae8e_row4_col2" class="data row4 col2" >NXG_A_1294</td>
#     </tr>
#     <tr>
#       <th id="T_eae8e_level0_row5" class="row_heading level0 row5" >EDIAm</th>
#       <td id="T_eae8e_row5_col0" class="data row5 col0" >0.320000</td>
#       <td id="T_eae8e_row5_col1" class="data row5 col1" >0.710000</td>
#       <td id="T_eae8e_row5_col2" class="data row5 col2" >0.380000</td>
#     </tr>
#     <tr>
#       <th id="T_eae8e_level0_row6" class="row_heading level0 row6" >chain</th>
#       <td id="T_eae8e_row6_col0" class="data row6 col0" >A</td>
#       <td id="T_eae8e_row6_col1" class="data row6 col1" >B</td>
#       <td id="T_eae8e_row6_col2" class="data row6 col2" >A</td>
#     </tr>
#     <tr>
#       <th id="T_eae8e_level0_row7" class="row_heading level0 row7" >HETCode</th>
#       <td id="T_eae8e_row7_col0" class="data row7 col0" >P86</td>
#       <td id="T_eae8e_row7_col1" class="data row7 col1" >P86</td>
#       <td id="T_eae8e_row7_col2" class="data row7 col2" >NXG</td>
#     </tr>
#     <tr>
#       <th id="T_eae8e_level0_row8" class="row_heading level0 row8" >noAltLocs</th>
#       <td id="T_eae8e_row8_col0" class="data row8 col0" >True</td>
#       <td id="T_eae8e_row8_col1" class="data row8 col1" >True</td>
#       <td id="T_eae8e_row8_col2" class="data row8 col2" >True</td>
#     </tr>
#     <tr>
#       <th id="T_eae8e_level0_row9" class="row_heading level0 row9" >heavyAtoms</th>
#       <td id="T_eae8e_row9_col0" class="data row9 col0" >21</td>
#       <td id="T_eae8e_row9_col1" class="data row9 col1" >21</td>
#       <td id="T_eae8e_row9_col2" class="data row9 col2" >24</td>
#     </tr>
#     <tr>
#       <th id="T_eae8e_level0_row10" class="row_heading level0 row10" >stereoCenters</th>
#       <td id="T_eae8e_row10_col0" class="data row10 col0" >0</td>
#       <td id="T_eae8e_row10_col1" class="data row10 col1" >0</td>
#       <td id="T_eae8e_row10_col2" class="data row10 col2" >4</td>
#     </tr>
#     <tr>
#       <th id="T_eae8e_level0_row11" class="row_heading level0 row11" >bondAnglesTest</th>
#       <td id="T_eae8e_row11_col0" class="data row11 col0" >False</td>
#       <td id="T_eae8e_row11_col1" class="data row11 col1" >False</td>
#       <td id="T_eae8e_row11_col2" class="data row11 col2" >False</td>
#     </tr>
#     <tr>
#       <th id="T_eae8e_level0_row12" class="row_heading level0 row12" >lipinskiDonors</th>
#       <td id="T_eae8e_row12_col0" class="data row12 col0" >1</td>
#       <td id="T_eae8e_row12_col1" class="data row12 col1" >1</td>
#       <td id="T_eae8e_row12_col2" class="data row12 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_eae8e_level0_row13" class="row_heading level0 row13" >maxAtomBFactor</th>
#       <td id="T_eae8e_row13_col0" class="data row13 col0" >0.000000</td>
#       <td id="T_eae8e_row13_col1" class="data row13 col1" >0.000000</td>
#       <td id="T_eae8e_row13_col2" class="data row13 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_eae8e_level0_row14" class="row_heading level0 row14" >bondLengthsTest</th>
#       <td id="T_eae8e_row14_col0" class="data row14 col0" >True</td>
#       <td id="T_eae8e_row14_col1" class="data row14 col1" >True</td>
#       <td id="T_eae8e_row14_col2" class="data row14 col2" >False</td>
#     </tr>
#     <tr>
#       <th id="T_eae8e_level0_row15" class="row_heading level0 row15" >molecularWeight</th>
#       <td id="T_eae8e_row15_col0" class="data row15 col0" >514.000000</td>
#       <td id="T_eae8e_row15_col1" class="data row15 col1" >514.000000</td>
#       <td id="T_eae8e_row15_col2" class="data row15 col2" >452.000000</td>
#     </tr>
#     <tr>
#       <th id="T_eae8e_level0_row16" class="row_heading level0 row16" >HETExclusionTest</th>
#       <td id="T_eae8e_row16_col0" class="data row16 col0" >True</td>
#       <td id="T_eae8e_row16_col1" class="data row16 col1" >True</td>
#       <td id="T_eae8e_row16_col2" class="data row16 col2" >True</td>
#     </tr>
#     <tr>
#       <th id="T_eae8e_level0_row17" class="row_heading level0 row17" >lipinskiAcceptors</th>
#       <td id="T_eae8e_row17_col0" class="data row17 col0" >3</td>
#       <td id="T_eae8e_row17_col1" class="data row17 col1" >3</td>
#       <td id="T_eae8e_row17_col2" class="data row17 col2" >4</td>
#     </tr>
#     <tr>
#       <th id="T_eae8e_level0_row18" class="row_heading level0 row18" >noCrystalContacts</th>
#       <td id="T_eae8e_row18_col0" class="data row18 col0" >False</td>
#       <td id="T_eae8e_row18_col1" class="data row18 col1" >True</td>
#       <td id="T_eae8e_row18_col2" class="data row18 col2" >False</td>
#     </tr>
#     <tr>
#       <th id="T_eae8e_level0_row19" class="row_heading level0 row19" >ringPlanarityTest</th>
#       <td id="T_eae8e_row19_col0" class="data row19 col0" >T

# %%
active_site_data = pd.DataFrame.from_dict(output_data['output_data']['active_sites'])
active_site_data.columns = ['Active_site_1', 'Active_site_2', 'Active_site_3']
active_site_data.style.apply(table_style, axis=1)
# Out:
# <style type="text/css">
# #T_fc0eb_row0_col0, #T_fc0eb_row0_col1, #T_fc0eb_row0_col2, #T_fc0eb_row1_col0, #T_fc0eb_row1_col1, #T_fc0eb_row1_col2, #T_fc0eb_row2_col0, #T_fc0eb_row2_col1, #T_fc0eb_row2_col2, #T_fc0eb_row3_col0, #T_fc0eb_row3_col1, #T_fc0eb_row3_col2, #T_fc0eb_row5_col0, #T_fc0eb_row5_col1, #T_fc0eb_row5_col2, #T_fc0eb_row7_col0, #T_fc0eb_row7_col1, #T_fc0eb_row7_col2, #T_fc0eb_row8_col0, #T_fc0eb_row8_col1, #T_fc0eb_row8_col2, #T_fc0eb_row9_col0, #T_fc0eb_row9_col1, #T_fc0eb_row9_col2 {
#   background-color: white;
# }
# #T_fc0eb_row4_col0, #T_fc0eb_row4_col1, #T_fc0eb_row4_col2, #T_fc0eb_row10_col0, #T_fc0eb_row10_col1, #T_fc0eb_row10_col2 {
#   background-color: red;
# }
# #T_fc0eb_row6_col0, #T_fc0eb_row6_col1, #T_fc0eb_row6_col2 {
#   background-color: lightblue;
# }
# </style>
# <table id="T_fc0eb_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Active_site_1</th>
#       <th class="col_heading level0 col1" >Active_site_2</th>
#       <th class="col_heading level0 col2" >Active_site_3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc0eb_level0_row0" class="row_heading level0 row0" >chains</th>
#       <td id="T_fc0eb_row0_col0" class="data row0 col0" >A,B</td>
#       <td id="T_fc0eb_row0_col1" class="data row0 col1" >A,B</td>
#       <td id="T_fc0eb_row0_col2" class="data row0 col2" >A,B</td>
#     </tr>
#     <tr>
#       <th id="T_fc0eb_level0_row1" class="row_heading level0 row1" >ligand</th>
#       <td id="T_fc0eb_row1_col0" class="data row1 col0" >P86_A_400</td>
#       <td id="T_fc0eb_row1_col1" class="data row1 col1" >P86_B_400</td>
#       <td id="T_fc0eb_row1_col2" class="data row1 col2" >NXG_A_1294</td>
#     </tr>
#     <tr>
#       <th id="T_fc0eb_level0_row2" class="row_heading level0 row2" >noAltLocs</th>
#       <td id="T_fc0eb_row2_col0" class="data row2 col0" >True</td>
#       <td id="T_fc0eb_row2_col1" class="data row2 col1" >True</td>
#       <td id="T_fc0eb_row2_col2" class="data row2 col2" >True</td>
#     </tr>
#     <tr>
#       <th id="T_fc0eb_level0_row3" class="row_heading level0 row3" >uniprotID</th>
#       <td id="T_fc0eb_row3_col0" class="data row3 col0" >P04637</td>
#       <td id="T_fc0eb_row3_col1" class="data row3 col1" >P04637</td>
#       <td id="T_fc0eb_row3_col2" class="data row3 col2" >P04637</td>
#     </tr>
#     <tr>
#       <th id="T_fc0eb_level0_row4" class="row_heading level0 row4" >bondAnglesTest</th>
#       <td id="T_fc0eb_row4_col0" class="data row4 col0" >False</td>
#       <td id="T_fc0eb_row4_col1" class="data row4 col1" >False</td>
#       <td id="T_fc0eb_row4_col2" class="data row4 col2" >False</td>
#     </tr>
#     <tr>
#       <th id="T_fc0eb_level0_row5" class="row_heading level0 row5" >bondLengthsTest</th>
#       <td id="T_fc0eb_row5_col0" class="data row5 col0" >True</td>
#       <td id="T_fc0eb_row5_col1" class="data row5 col1" >True</td>
#       <td id="T_fc0eb_row5_col2" class="data row5 col2" >True</td>
#     </tr>
#     <tr>
#       <th id="T_fc0eb_level0_row6" class="row_heading level0 row6" >residueEDIATest</th>
#       <td id="T_fc0eb_row6_col0" class="data row6 col0" >True</td>
#       <td id="T_fc0eb_row6_col1" class="data row6 col1" >False</td>
#       <td id="T_fc0eb_row6_col2" class="data row6 col2" >True</td>
#     </tr>
#     <tr>
#       <th id="T_fc0eb_level0_row7" class="row_heading level0 row7" >bFactorRatioTest</th>
#       <td id="T_fc0eb_row7_col0" class="data row7 col0" >True</td>
#       <td id="T_fc0eb_row7_col1" class="data row7 col1" >True</td>
#       <td id="T_fc0eb_row7_col2" class="data row7 col2" >True</td>
#     </tr>
#     <tr>
#       <th id="T_fc0eb_level0_row8" class="row_heading level0 row8" >noIntermolecularClash</th>
#       <td id="T_fc0eb_row8_col0" class="data row8 col0" >True</td>
#       <td id="T_fc0eb_row8_col1" class="data row8 col1" >True</td>
#       <td id="T_fc0eb_row8_col2" class="data row8 col2" >True</td>
#     </tr>
#     <tr>
#       <th id="T_fc0eb_level0_row9" class="row_heading level0 row9" >noIntramolecularClash</th>
#       <td id="T_fc0eb_row9_col0" class="data row9 col0" >True</td>
#       <td id="T_fc0eb_row9_col1" class="data row9 col1" >True</td>
#       <td id="T_fc0eb_row9_col2" class="data row9 col2" >True</td>
#     </tr>
#     <tr>
#       <th id="T_fc0eb_level0_row10" class="row_heading level0 row10" >activeSiteStructureProfilerTests</th>
#       <td id="T_fc0eb_row10_col0" class="data row10 col0" >False</td>
#       <td id="T_fc0eb_row10_col1" class="data row10 col1" >False</td>
#       <td id="T_fc0eb_row10_col2" class="data row10 col2" >False</td>
#     </tr>
#   </tbody>
# </table>
